# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import os
# %matplotlib inline
plt.style.use('seaborn-darkgrid')
from scipy.stats import chi2_contingency
path = os.getcwd()
import numpy as np
import rpy2.robjects.numpy2ri
from rpy2.robjects.packages import importr
rpy2.robjects.numpy2ri.activate()


cod_df = pd.read_csv(f'{path}\\final_filtered_with_codons.csv',index_col = 0)

# %%
cod_df = cod_df.dropna(subset = ['trnS','trnL'])

# %%
cod_df.value_counts('phylum')
# Out:
# phylum
# Chordata           3001
# Arthropoda          641
# Mollusca             98
# Nematoda             49
# Echinodermata        38
# Platyhelminthes      36
# Annelida             32
# Porifera             26
# Nemertea             11
# Entoprocta            8
# Rotifera              4
# Xenacoelomorpha       4
# Hemichordata          2
# Bryozoa               2
# Brachiopoda           2
# Priapulida            2
# Phoronida             1
# Tardigrada            1
# dtype: int64

# %%
sns.countplot(y = 'phylum', data = cod_df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='phylum'>

# %%
cod_df.trnS = cod_df.trnS.astype(bool)
cod_df.trnL = cod_df.trnL.astype(bool)
cod_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3958 entries, Cyprinus carpio to Mastigoproctus giganteus
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RefSeq           3958 non-null   object
#  1   kingdom          3958 non-null   object
#  2   phylum           3958 non-null   object
#  3   class            3800 non-null   object
#  4   order            3934 non-null   object
#  5   family           3929 non-null   object
#  6   genus            3955 non-null   object
#  7   Gene_order       3958 non-null   object
#  8   Gene_locations   3958 non-null   object
#  9   Notes            3958 non-null   object
#  10  tRNA_validation  3958 non-null   object
#  11  Intron           3958 non-null   bool
#  12  Full             3958 non-null   bool
#  13  genetic_code     3958 non-null   int64
#  14  Haplotype        43 non-null     object
#  15  topology         3958 non-null   object
#  16  not_valid        3958 non-null   bool
#  17  Genes            3958 non-null   int64
#  18  non_trna_Genes   3958 non-null   int64
#  19  trnS             3958 non-null   bool
#  20  trnL             3958 non-null   bool
# dtypes: bool(5), int64(3), object(13)
# memory usage: 674.0+ KB

# %%
wanted = ['Mollusca','Nematoda','Chordata','Arthropoda','Echinodermata']
cod_df_filt = cod_df[cod_df.phylum.isin(wanted)]
group = cod_df_filt.groupby('phylum')[['trnS','trnL']].mean() * 100
display(group)
group.reset_index(inplace = True)
group = group.melt(id_vars = 'phylum', value_vars = ['trnS','trnL'], var_name = 'tRNA', value_name = 'Discrepancy')
# Out:
#                     trnS        trnL
# phylum
# Arthropoda     85.647426   90.171607
# Chordata       92.269244   92.769077
# Echinodermata  50.000000   81.578947
# Mollusca       75.510204   85.714286
# Nematoda       95.918367  100.000000

# %%
fig, ax = plt.subplots(figsize = (12,8))
ax = sns.barplot(x = 'phylum', y = 'Discrepancy', hue = 'tRNA', ax = ax, data = group)
plt.yticks(ticks = list(range(0,101,10)), labels = [f'{i}%' for i in range(0,101,10)], fontsize = 12)
plt.ylabel('% tRNA-codon agreement', fontsize = 14)
plt.xlabel('Phylum', fontsize = 14)
plt.xticks(fontsize = 12)
plt.setp(ax.get_legend().get_texts(), fontsize='12')
plt.setp(ax.get_legend().get_title(), fontsize='14')
x_offset = 0.2
y_offset = 0.5
x = np.tile(np.arange(len(group.phylum)/2),2)
c=0
for index, row in group.iterrows():
    trna = row.tRNA
    if trna == 'trnS':
        ax.text(x[c] - x_offset,row.Discrepancy+y_offset,f'{round(row.Discrepancy,2)}%', color = 'black', ha='center', fontsize = 12, fontstyle = 'oblique')
    else:
        ax.text(x[c] + x_offset,row.Discrepancy+y_offset,f'{round(row.Discrepancy,2)}%', color = 'black', ha='center', fontsize = 12, fontstyle = 'oblique')
    c+=1

plt.savefig(r'C:\Users\noam1\Desktop\The dynamics of the mitochondrial genome (paper prep)\figures\codon_disc_graph.pdf')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1256/236496648.py in <module>
#      19     c+=1
#      20
# ---> 21 plt.savefig(r'C:\Users\noam1\Desktop\The dynamics of the mitochondrial genome (paper prep)\figures\codon_disc_graph.pdf')
#
# c:\users\noam1\appdata\local\programs\python\python39\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     964 def savefig(*args, **kwargs):
#     965     fig = gcf()
# --> 966     res = fig.savefig(*args, **kwargs)
#     967     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     968     return res
#
# c:\users\noam1\appdata\local\programs\python\python39\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    3003                 patch.set_edgecolor('none')
#    3004
# -> 3005         self.canvas.print_figure(fname, **kwargs)
#    3006
#    3007         if transparent:
#
# c:\users\noam1\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2253                 # force the figure dpi to 72), so we need to set it again here.
#    2254                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2255                     result = print_method(
#    2256                         filename,
#    2257                         facecolor=facecolor,
#
# c:\users\noam1\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# c:\users\noam1\appdata\local\programs\python\python39\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# c:\users\noam1\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_pdf.py in print_pdf(self, filename, dpi, bbox_inches_restore, metadata)
#    2716             file = filename._file
#    2717         else:
# -> 2718             file = PdfFile(filename, metadata=metadata)
#    2719         try:
#    2720             file.newPage(width, height)
#
# c:\users\noam1\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_pdf.py in __init__(self, filename, metadata)
#     635         self.original_file_like = None
#     636         self.tell_base = 0
# --> 637         fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     638         if not opened:
#     639             try:
#
# c:\users\noam1\appdata\local\programs\python\python39\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     460             fh = bz2.BZ2File(fname, flag)
#     461         else:
# --> 462             fh = open(fname, flag, encoding=encoding)
#     463         opened = True
#     464     elif hasattr(fname, 'seek'):
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\noam1\\Desktop\\The dynamics of the mitochondrial genome (paper prep)\\figures\\codon_disc_graph.pdf'

# %%
cod_df_filt[cod_df_filt.phylum == 'Echinodermata']
# Out:
#                                         RefSeq  kingdom         phylum  \
# organism
# Acanthaster brevispinus            NC_007789.1  Metazoa  Echinodermata
# Acanthaster planci                 NC_007788.1  Metazoa  Echinodermata
# Amphipholis squamata               NC_013876.1  Metazoa  Echinodermata
# Amphiura digitula                  NC_042738.1  Metazoa  Echinodermata
# Amphiura sinicola                  NC_045938.1  Metazoa  Echinodermata
# Apostichopus japonicus             NC_012616.1  Metazoa  Echinodermata
# Arbacia lixula                     NC_001770.1  Metazoa  Echinodermata
# Asterias amurensis                 NC_006665.1  Metazoa  Echinodermata
# Astropecten polyacanthus           NC_006666.1  Metazoa  Echinodermata
# Astrospartus mediterraneus         NC_013878.1  Metazoa  Echinodermata
# Echinocardium cordatum             NC_013881.1  Metazoa  Echinodermata
# Florometra serratissima            NC_001878.1  Metazoa  Echinodermata
# Holothuria forskali                NC_013884.1  Metazoa  Echinodermata
# Holothuria pervicax                NC_045853.1  Metazoa  Echinodermata
# Holothuria scabra                  NC_027086.1  Metazoa  Echinodermata
# Luidia quinaria                    NC_006664.1  Metazoa  Echinodermata
# Acanthaster brevispinus            ['-nad1', '-trnL(UUR)', 'trnG', '-trnY', 'trnD...
# Acanthaster planci                 ['-nad1', '-trnL(UUR)', 'trnG', '-trnY', 'trnD...
# Amphipholis squamata               ['-nad1', '-trnL(UUR)', '-trnN', 'trnQ', 'trnC...
# Amphiura digitula                  ['-nad1', '-trnL(UUA)', '-trnN', 'trnQ', 'trnC...
# Amphiura sinicola                  ['-nad1', '-trnL(UUA)', '-trnN', 'trnQ', 'trnC...
# Apostichopus japonicus             ['nad1', 'trnI', 'nad2', 'rrnL', 'cox1', 'trnR...
# Arbacia lixula                     ['nad1', 'trnI', 'nad2', 'rrnL', 'cox1', 'trnR...
# Asterias amurensis                 ['-nad1', '-trnL(UUR)', '-trnG', '-trnY', 'trn...
# Astropecten polyacanthus           ['-nad1', '-trnL(UUR)', '-trnG', '-trnY', 'trn...
# Astrospartus mediterraneus         ['-nad1', '-trnL(UUR)', '-trnN', 'trnQ', 'trnC...
# Echinocardium cordatum             ['nad1', 'trnI', 'nad2', 'rrnL', 'cox1', 'trnR...
# Florometra serratissima            ['-nad1', 'cox1', 'trnR', 'nad4L', 'cox2', 'tr...
# Holothuria forskali                ['nad1', 'trnI', 'nad2', 'rrnL', 'cox1', 'trnR...
# Holothuria pervicax                ['nad1', 'trnI', 'nad2', 'rrnL', 'cox1', 'trnR...
# Holothuria scabra                  ['nad1', 'trnI(AUY)', 'nad2', 'rrnL', 'cox1', ...
# Luidia quinaria                    ['-nad1', '-trnL(UUR)', '-trnG', '-trnY', '-tr...
# Neogymnocrinus richeri             ['-nad1', 'cox1', 'trnR', 'cox2', 'trnK', 'atp...
# Ophiarachnella gorgonia            ['-nad1', '-trnL(UUA)', '-trnN', 'trnQ', 'trnC...
# Ophiocomina nigra                  ['-nad1', '-trnL(UUR)', '-trnN', 'trnQ', 'trnC...
# Ophiomastix mixta                  ['-nad1', '-trnL(UUA)', '-trnN', 'trnQ', 'trnC...
# Ophiopholis japonica               ['-nad1', '-trnL(UUA)', '-trnN', 'trnQ', 'trnC...
# Ophiopholis mirabilis              ['-nad1', '-trnL(UUA)', '-trnN', 'trnQ', 'trnC...
# Ophioplocus japonicus              ['-nad1', '-trnL(UUA)', '-trnN', 'trnQ', 'trnC...
# Ophiura albida                     ['nad1', 'trnI', 'nad2', 'trnD', 'cob', 'trnT'...
# Ophiura sarsii                     ['nad1', 'trnI', 'nad2', 'trnD', 'cob', 'trnT'...
# Ophiura luetkenii                  ['nad1', 'trnI', 'nad2', 'trnD', 'cob', 'trnT'...
# Paracentrotus lividus              ['nad1', 'trnI', 'nad2', 'rrnL', 'cox1', 'trnR...
# Parastichopus nigripunctatus       ['nad1', 'trnI(AUC)', 'nad2', 'rrnL', 'cox1', ...
# Stichopus horrens                  ['nad1', 'trnI', 'nad2', 'rrnL', 'cox1', 'trnR...
# Stichopus sp.                      ['nad1', 'trnI', 'nad2', 'rrnL', 'cox1', 'trnR...
# Strongylocentrotus droebachiensis  ['nad1', 'trnI', 'nad2', 'rrnL', 'cox1', 'trnR...
# Strongylocentrotus pallidus        ['nad1', 'trnI', 'nad2', 'rrnL', 'cox1', 'trnR...
# Strongylocentrotus purpuratus      ['nad1', 'trnI', 'nad2', 'rrnL', 'cox1', 'trnR...
# Cucumaria miniata                  ['nad1', 'trnI', 'nad2', 'rrnL', 'cox1', 'trnR...
# Patiria pectinifera                ['-nad1', '-trnL(UUR)', '-trnG', '-trnY', 'trn...
# Phanogenia gracilis                ['-nad1', 'cox1', 'trnR', 'nad4L', 'cox2', 'tr...
# Ophiura lutkeni                    ['nad1', 'trnI', 'nad2', 'trnD', 'cob', 'trnT'...
# Patiria pectinifera                ['10173:11154:-1', '11154:11226:-1', '11256:11...
# Phanogenia gracilis                ['6065:7040:-1', '7116:8670:1', '8672:8741:1',...
# Ophiura lutkeni                    ['13784:14786:1', '14786:14858:1', '14859:1591...
# Luidia quinalia                    ['2353:3331:-1', '3331:3403:-1', '3431:3501:-1...
#
#                                                                                Notes  \
# organism
# Acanthaster brevispinus            ['None', 'None', 'None', 'None', 'None', 'None...
# Acanthaster planci                 ['None', 'None', 'None', 'None', 'None', 'None...
# Amphipholis squamata               ['None', 'None', 'None', 'None', 'None', 'None...
# Amphiura digitula                  ['None', 'None', 'None', 'None', 'None', 'None...
# Amphiura sinicola                  ['["TAA stop codon is completed by the additio...
# Apostichopus japonicus             ['None', 'None', 'None', "['16S ribosomal RNA'...
# Arbacia lixula                     ['None', 'None', 'None', 'None', 'None', 'None...
# Asterias amurensis                 ['None', 'None', 'None', 'None', 'None', 'None...
# Astropecten polyacanthus           ['["TAA stop codon is completed by the additio...
# Astrospartus mediterraneus         ['None', 'None', 'None', 'None', 'None', 'None...
# Echinocardium cordatum             ['None', 'None', 'None', "['16S ribosomal RNA'...
# Florometra serratissima            ['["TAA stop codon is completed by the additio...
# Holothuria forskali                ['None', 'None', 'None', "['16S ribosomal RNA'...
# Holothuria pervicax                ['None', 'None', 'None', 'None', 'None', 'None...
# Holothuria scabra                  ['None', 'None', 'None', 'None', 'None', 'None...
# Luidia quinaria                    ['None', 'None', 'None', 'None', 'None', 'None...
# Neogymnocrinus richeri             ['["TAA stop codon is completed by the additio...
# Ophiarachnella gorgonia            ['None', 'None', 'None', 'None', 'None', 'None...
# Ophiocomina nigra                  ['None', 'None', 'None', 'None', 'None', 'None...
# Ophiomastix mixta                  ['None', 'None', 'None', 'None', 'None', 'None...
# Ophiopholis japonica               ['None', 'None', 'None', 'None', 'None', 'None...
# Ophiopholis mirabilis              ['None', 'None', 'None', 'None', 'None', 'None...
# Ophioplocus japonicus              ['None', 'None', 'None', 'None', 'None', 'None...
# Ophiura albida                     ['None', 'None', 'None', 'None', 'None', 'None...
# Ophiura sarsii                     ['None', 'None', 'None', 'None', '["TAA stop c...
# Ophiura luetkenii                  ['None', 'None', 'None', 'None', '["TAA stop c...
# Paracentrotus lividus              ['None', 'None', 'None', 'None', 'None', 'None...
# Parastichopus nigripunctatus       ['None', 'None', 'None', "['16S ribosomal RNA'...
# Stichopus horrens                  ['None', 'None', 'None', "['16S ribosomal RNA'...
# Stichopus sp.                      ['None', 'None', 'None', "['16S ribosomal RNA'...
# Strongylocentrotus droebachiensis  ['None', 'None', 'None', "['16S ribosomal RNA'...
# Strongylocentrotus pallidus        ['None', 'None', 'None', "['16S ribosomal RNA'...
# Strongylocentrotus purpuratus      ['None', 'None', 'None', 'None', 'None', 'None...
# Cucumaria miniata                  ['None', 'None', 'None', 'None', 'None', 'None...
# Patiria pectinifera                ['None', 'None', 'None', 'None', 'None', 'None...
# Phanogenia gracilis                ['None', 'None', 'None', 'None', 'None', 'None...
# Ophiura lutkeni                    ['None', 'None', 'None', 'None', '["TAA stop c...
# Luidia quinalia                    ['None', 'None', 'None', 'None', "['added by M...
#
#                                    ... Intron  Full  genetic_code  Haplotype  \
# organism                           ...
# Acanthaster brevispinus            ...  False  True             9        NaN
# Acanthaster planci                 ...  False  True             9        NaN
# Amphipholis squamata               ...  False  True             9        NaN
# Amphiura digitula                  ...  False  True             9        NaN
# Amphiura sinicola                  ...  False  True             9        NaN
# Apostichopus japonicus             ...  False  True             9        NaN
# Arbacia lixula                     ...  False  True             9        NaN
# Asterias amurensis                 ...  False  True             9        NaN
# Astropecten polyacanthus           ...  False  True             9        NaN
# Astrospartus mediterraneus         ...  False  True             9        NaN
# Echinocardium cordatum             ...  False  True             9        NaN
# Florometra serratissima            ...  False  True             9        NaN
# Holothuria forskali                ...  False  True             9        NaN
# Holothuria pervicax                ...  False  True             9        NaN
# Holothuria scabra                  ...  False  True             9        NaN
# Luidia quinaria                    ...  False  True             9        NaN
# Neogymnocrinus richeri             ...  False  True             9        NaN
# Ophiarachnella gorgonia            ...  False  True             9        NaN
# Ophiocomina nigra                  ...  False  True             9        NaN
# Ophiomastix mixta                  ...  False  True             9        NaN
# Ophiopholis japonica               ...  False  True             9        NaN
# Ophiopholis mirabilis              ...  False  True             9        NaN
# Ophioplocus japonicus              ...  False  True             9        NaN
# Ophiura albida                     ...  False  True             9        NaN
# Ophiura sarsii                     ...  False  True             9        NaN
# Ophiura luetkenii                  ...  False  True             9        NaN
# Paracentrotus lividus              ...  False  True             9        NaN
# Parastichopus nigripunctatus       ...  False  True             9        NaN
# Stichopus horrens                  ...  False  True             9        NaN
# Stichopus sp.                      ...  False  True             9        NaN
# Strongylocentrotus droebachiensis  ...  False  True             9        NaN
# Strongylocentrotus pallidus        ...  False  True             9        NaN
# Strongylocentrotus purpuratus      ...  False  True             9        NaN
# Cucumaria miniata                  ...  False  True             9        NaN
# Patiria pectinifera                ...  False  True             9        NaN
# Phanogenia gracilis                ...  False  True             9        NaN
# Ophiura lutkeni                    ...  False  True             9        NaN
# Luidia quinalia                    ...  False  True             9        NaN
#
#                                    topology not_valid  Genes  non_trna_Genes  \
# organism
# Acanthaster brevispinus            circular     False     37              15
# Acanthaster planci                 circular     False     37              15
# Amphipholis squamata               circular     False     37              15
# Amphiura digitula                  circular     False     37              15
# Amphiura sinicola                  circular     False     37              15
# Apostichopus japonicus             circular     False     37              15
# Arbacia lixula                     circular     False     37              15
# Asterias amurensis                 circular     False     32              13
# Astropecten polyacanthus           circular     False     32              13
# Astrospartus mediterraneus         circular     False     37              15
# Echinocardium cordatum             circular     False     37              15
# Florometra serratissima            circular     False     37              15
# Holothuria forskali                circular     False     37              15
# Holothuria pervicax                circular     False     37              15
# Holothuria scabra                  circular     False     37              15
# Luidia quinaria                    circular     False     32              13
# Neogymnocrinus richeri             circular     False     37              15
# Ophiarachnella gorgonia            circular     False     37              15
# Ophiocomina nigra                  circular     False     37              15
# Ophiomastix mixta                  circular     False     37              15
# Ophiopholis japonica               circular     False     37              15
# Ophiopholis mirabilis              circular     False     37              15
# Ophioplocus japonicus              circular     False     37              15
# Ophiura albida                     circular     False     37              15
# Ophiura sarsii                     circular     False     37              15
# Ophiura luetkenii                  circular     False     37              15
# Paracentrotus lividus              circular     False     37              15
# Parastichopus nigripunctatus       circular     False     37              15
# Stichopus horrens                  circular     False     37              15
# Stichopus sp.                      circular     False     37              15
# Strongylocentrotus droebachiensis  circular     False     37              15
# Strongylocentrotus pallidus        circular     False     37              15
# Strongylocentrotus purpuratus      circular     False     37              15
# Cucumaria miniata                  circular     False     37              15
# Patiria pectinifera                circular     False     37              15
# Phanogenia gracilis                circular     False     37              15
# Ophiura lutkeni                    circular     False     37              15
# Luidia quinalia                    circular     False     37              15
#
#                                     trnS   trnL
# organism
# Acanthaster brevispinus             True   True
# Acanthaster planci                 False   True
# Amphipholis squamata               False   True
# Amphiura digitula                  False  False
# Amphiura sinicola                  False  False
# Apostichopus japonicus              True   True
# Arbacia lixula                      True   True
# Asterias amurensis                 False   True
# Astropecten polyacanthus           False   True
# Astrospartus mediterraneus         False   True
# Echinocardium cordatum             False   True
# Florometra serratissima             True   True
# Holothuria forskali                False   True
# Holothuria pervicax                False   True
# Holothuria scabra                   True   True
# Luidia quinaria                    False   True
# Neogymnocrinus richeri              True   True
# Ophiarachnella gorgonia            False  False
# Ophiocomina nigra                  False   True
# Ophiomastix mixta                  False  False
# Ophiopholis japonica               False  False
# Ophiopholis mirabilis              False  False
# Ophioplocus japonicus               True  False
# Ophiura albida                     False   True
# Ophiura sarsii                     False   True
# Ophiura luetkenii                   True   True
# Paracentrotus lividus               True   True
# Parastichopus nigripunctatus        True   True
# Stichopus horrens                   True   True
# Stichopus sp.                       True   True
# Strongylocentrotus droebachiensis   True   True
# Strongylocentrotus pallidus         True   True
# Strongylocentrotus purpuratus       True   True
# Cucumaria miniata                   True   True
# Patiria pectinifera                False   True
# Phanogenia gracilis                 True   True
# Ophiura lutkeni                     True   True
# Luidia quinalia                     True   True
#
# [38 rows x 21 columns]

# %%
stats = importr('stats')
m = np.array(trns_cross)
res = stats.fisher_test(m)
print('p-value: {}'.format(res[0][0]))
# Out:
# p-value: 1.5978039652970065e-10

# %%
group
# Out:
#        phylum  tRNA  Discrepancy
# 0  Arthropoda  trnS    85.647426
# 1    Chordata  trnS    92.269244
# 2    Mollusca  trnS    75.510204
# 3    Nematoda  trnS    95.918367
# 4  Arthropoda  trnL    90.171607
# 5    Chordata  trnL    92.769077
# 6    Mollusca  trnL    85.714286
# 7    Nematoda  trnL   100.000000
